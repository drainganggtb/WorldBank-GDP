# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
co2_emmisions = pd.read_csv("CO_2_emissions.csv")

# %%
co2_emmisions
# Out:
#                                           Series Name     Series Code  \
# 0              CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC
# 1              CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC
# 2              CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC
# 3              CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC
# 4              CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC
# ..                                                ...             ...
# 217                                               NaN             NaN
# 218                                               NaN             NaN
# 219                                               NaN             NaN
# 220  Data from database: World Development Indicators             NaN
# 221                          Last Updated: 10/15/2020             NaN
#
#        Country Name Country Code     1971 [YR1971]     1972 [YR1972]  \
# ...

# %%
co2_emmisions_clean = co2_emmisions.drop(columns=["Series Name", "Series Code", "Country Code"])

co2_emmisions_clean
# Out:
#        Country Name     1971 [YR1971]     1972 [YR1972]      1973 [YR1973]  \
# 0       Afghanistan  0.16520832089736  0.12999559417753  0.135366587543459
# 1           Albania  1.98949792330655  2.51591439803203   2.30389741687392
# 2           Algeria  1.25527052060045  1.85461177195589   2.43878057203056
# 3    American Samoa                ..                ..                 ..
# 4           Andorra                ..                ..                 ..
# ..              ...               ...               ...                ...
# 217             NaN               NaN               NaN                NaN
# 218             NaN               NaN               NaN                NaN
# 219             NaN               NaN               NaN                NaN
# 220             NaN               NaN               NaN                NaN
# 221             NaN               NaN               NaN                NaN
#
#          1974 [YR1974]      1975 [YR1975]      1976 [YR1976]  \
# ...

# %%
co2_emmisions_clean = co2_emmisions_clean.dropna(how = "all")
co2_emmisions_clean
# Out:
#               Country Name       1971 [YR1971]       1972 [YR1972]  \
# 0              Afghanistan    0.16520832089736    0.12999559417753
# 1                  Albania    1.98949792330655    2.51591439803203
# 2                  Algeria    1.25527052060045    1.85461177195589
# 3           American Samoa                  ..                  ..
# 4                  Andorra                  ..                  ..
# ..                     ...                 ...                 ...
# 212  Virgin Islands (U.S.)                  ..                  ..
# 213     West Bank and Gaza                  ..                  ..
# 214            Yemen, Rep.  0.0343943475458101  0.0395931570466127
# 215                 Zambia   0.877860930574566   0.910556328526385
# 216               Zimbabwe    1.59615788403175    1.44963165618918
#
#           1973 [YR1973]       1974 [YR1974]       1975 [YR1975]  \
# 0     0.135366587543459   0.154503240567311   0.167612355743012
# ...

# %%
co2_emmisions_clean = co2_emmisions_clean.rename(columns={'1971 [YR1971]' : "1971", 
                                                          '1972 [YR1972]' : "1972", 
                                                          '1973 [YR1973]' : "1973",
                                                          '1974 [YR1974]' : "1974", 
                                                          '1975 [YR1975]' : "1975", 
                                                          '1976 [YR1976]' : "1976", 
                                                          '1977 [YR1977]' : "1977",
                                                          '1978 [YR1978]' : "1978", 
                                                          '1979 [YR1979]' : "1979", 
                                                          '1980 [YR1980]' : "1980", 
                                                          '1981 [YR1981]' : "1981", 
                                                          '1982 [YR1982]' : "1982", 
                                                          '1983 [YR1983]' : "1983", 
                                                          '1984 [YR1984]' : "1984", 
                                                          '1985 [YR1985]' : "1985",
                                                          '1986 [YR1986]' : "1986", 
                                                          '1987 [YR1987]' : "1987", 
                                                          '1988 [YR1988]' : "1988", 
                                                          '1989 [YR1989]' : "1989",
                                                          '1990 [YR1990]' : "1990", 
                                                          '1991 [YR1991]' : "1991", 
                                                          '1992 [YR1992]' : "1992",
                                                          '1993 [YR1993]' : "1993",
                                                          '1994 [YR1994]' : "1994", 
                                                          '1995 [YR1995]' : "1995", 
                                                          '1996 [YR1996]' : "1996", 
                                                          '1997 [YR1997]' : "1997",
                                                          '1998 [YR1998]' : "1998", 
                                                          '1999 [YR1999]' : "1999", 
                                                          '2000 [YR2000]' : "2000", 
                                                          '2001 [YR2001]' : "2001",
                                                          '2002 [YR2002]' : "2002", 
                                                          '2003 [YR2003]' : "2003", 
                                                          '2004 [YR2004]' : "2004", 
                                                          '2005 [YR2005]' : "2005",
                                                          '2006 [YR2006]' : "2006", 
                                                          '2007 [YR2007]' : "2007", 
                                                          '2008 [YR2008]' : "2008", 
                                                          '2009 [YR2009]' : "2009",
                                                          '2010 [YR2010]' : "2010", 
                                                          '2011 [YR2011]' : "2011", 
                                                          '2012 [YR2012]' : "2012", 
                                                          '2013 [YR2013]' : "2013",
                                                          '2014 [YR2014]' : "2014", 
                                                          '2015 [YR2015]' : "2015", 
                                                          '2016 [YR2016]' : "2016"
                                                         })

# %%
co2_emmisions_clean = co2_emmisions_clean.replace("..", "")

# %%
co2_emmisions_clean["1980"]
# Out:
# 0      0.131782918458271
# 1       1.93505831031996
# 2       3.46064609907623
# 3
# 4
#              ...
# 212
# 213
# 214    0.150523464290274
# 215    0.603456357632021
# 216     1.30076462241841
# Name: 1980, Length: 217, dtype: object

# %%
co2_emmisions_clean.columns
# Out:
# Index(['Country Name', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016'],
#       dtype='object')

# %%
co2_emmisions_clean
# Out:
#               Country Name                1971                1972  \
# 0              Afghanistan    0.16520832089736    0.12999559417753
# 1                  Albania    1.98949792330655    2.51591439803203
# 2                  Algeria    1.25527052060045    1.85461177195589
# 3           American Samoa
# 4                  Andorra
# ..                     ...                 ...                 ...
# 212  Virgin Islands (U.S.)
# 213     West Bank and Gaza
# 214            Yemen, Rep.  0.0343943475458101  0.0395931570466127
# 215                 Zambia   0.877860930574566   0.910556328526385
# 216               Zimbabwe    1.59615788403175    1.44963165618918
#
#                    1973                1974                1975  \
# 0     0.135366587543459   0.154503240567311   0.167612355743012
# 1      2.30389741687392    1.84900669071079    1.91063363704144
# 2      2.43878057203056    1.97575810304337    1.92869762213411
# 3
# 4
# ...

# %%
co2_emmisions_clean = co2_emmisions_clean.dropna(subset=["1971 [YR1971]"])
co2_emmisions_clean
# Out:
#               Country Name       1971 [YR1971]       1972 [YR1972]  \
# 0              Afghanistan    0.16520832089736    0.12999559417753
# 1                  Albania    1.98949792330655    2.51591439803203
# 2                  Algeria    1.25527052060045    1.85461177195589
# 3           American Samoa                  ..                  ..
# 4                  Andorra                  ..                  ..
# ..                     ...                 ...                 ...
# 212  Virgin Islands (U.S.)                  ..                  ..
# 213     West Bank and Gaza                  ..                  ..
# 214            Yemen, Rep.  0.0343943475458101  0.0395931570466127
# 215                 Zambia   0.877860930574566   0.910556328526385
# 216               Zimbabwe    1.59615788403175    1.44963165618918
#
#           1973 [YR1973]       1974 [YR1974]       1975 [YR1975]  \
# 0     0.135366587543459   0.154503240567311   0.167612355743012
# ...

# %%
co2_emmisions_clean.columns
# Out:
# Index(['Country Name', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016'],
#       dtype='object')

# %%
co2_mean = []

count = 0

columns=['1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016']

co2_emmisions_clean[columns] = co2_emmisions_clean[columns].apply(pd.to_numeric)

years=['1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016']



for i in columns:
    count = count + 1
    co2_mean.append(co2_emmisions_clean[str(i)].mean())

# %%
co2_avg = pd.DataFrame()
co2_avg["Years"] = years
co2_avg["CO2 Metric Tons/Capita"] = co2_mean

co2_avg
# Out:
#    Years  CO2 Metric Tons/Capita
# 0   1971                6.306819
# 1   1972                6.318522
# 2   1973                6.810799
# 3   1974                6.308267
# 4   1975                5.783169
# 5   1976                6.875580
# 6   1977                6.002959
# 7   1978                5.853509
# 8   1979                5.946353
# 9   1980                5.871322
# 10  1981                5.276077
# 11  1982                5.247026
# 12  1983                4.545503
# 13  1984                5.459229
# 14  1985                5.797262
# 15  1986                4.231046
# 16  1987                4.263720
# 17  1988                4.422296
# 18  1989                4.577385
# 19  1990                4.221402
# 20  1991                4.292255
# 21  1992                4.529104
# 22  1993                4.564090
# 23  1994                4.487511
# 24  1995                4.544010
# 25  1996                4.615610
# 26  1997                4.637908
# ...

# %%
plt.figure(figsize=(16, 8))
x_axis = co2_avg["Years"]
y_axis = co2_avg["CO2 Metric Tons/Capita"]

plt.plot(x_axis,y_axis, marker = "o", color = "r")

plt.show()
