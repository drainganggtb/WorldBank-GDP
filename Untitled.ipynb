# %%
import pandas as pd

# %%
gdp = pd.read_csv('GDP.csv')

# %%
gdp
# Out:
#      Country Name Country Code         Indicator Name     Indicator Code  \
# 0           Aruba          ABW  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 1     Afghanistan          AFG  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 2          Angola          AGO  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 3         Albania          ALB  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 4         Andorra          AND  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# ..            ...          ...                    ...                ...
# 259        Kosovo          XKX  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 260   Yemen, Rep.          YEM  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 261  South Africa          ZAF  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 262        Zambia          ZMB  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 263      Zimbabwe          ZWE  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
#
#      1960      1961      1962      1963       1964       1965  ...       2011  \
# ...

# %%
# Remove any rows with no vlaues
gdp=gdp.dropna(how='all')

# %%
# Remove Unnecessary columns
gdp = gdp.drop(gdp.loc[:,'Country Code':'1999'].columns,axis=1)

# %%
gdp
# Out:
#      Country Name      2000       2001       2002       2003       2004  \
# 0           Aruba  7.616588  -2.971257  -3.273646   1.975547   7.911563
# 1     Afghanistan       NaN        NaN        NaN   8.832278   1.414118
# 2          Angola  3.054624   4.205999  13.665687   2.989850  10.952862
# 3         Albania  6.950036   8.290070   4.539961   5.530051   5.509999
# 4         Andorra  3.528361   8.119358   4.546362   8.694204   8.135676
# ..            ...       ...        ...        ...        ...        ...
# 259        Kosovo       NaN  26.973918  -0.700948   5.980146   2.612127
# 260   Yemen, Rep.  6.181916   3.803646   3.935232   3.747398   3.972696
# 261  South Africa  4.200003   2.699995   3.700382   2.949079   4.554553
# 262        Zambia  3.897323   5.316868   4.506014   6.944974   7.032395
# 263      Zimbabwe -3.059190   1.439615  -8.894024 -16.995075  -5.807538
#
#           2005       2006       2007       2008  ...       2011       2012  \
# ...

# %%
gdp = gdp.drop(columns='2020')

# %%
gdp = gdp.dropna(subset=['2001'])

# %%
gdp['2001'].describe()
# Out:
# count    243.000000
# mean       3.410676
# std        5.407363
# min       -9.310638
# 25%        1.328677
# 50%        3.185030
# 75%        4.814709
# max       63.379875
# Name: 2001, dtype: float64

# %%
828/217
# Out:
# 3.815668202764977
