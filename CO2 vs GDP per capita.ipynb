# %%
import pandas as pd
import humanize

# %%
datafile = 'co2-emissions-vs-gdp.csv'

# %%
pd.set_option('display.max_rows',10)
df = pd.read_csv(datafile)
df
# Out:
#               Entity      Code  Year  Total population (Gapminder, HYDE & UN)  \
# 0           Abkhazia  OWID_ABK  2015                                      NaN
# 1        Afghanistan       AFG  1800                                3280000.0
# 2        Afghanistan       AFG  1801                                3280000.0
# 3        Afghanistan       AFG  1802                                3280000.0
# 4        Afghanistan       AFG  1803                                3280000.0
# ...              ...       ...   ...                                      ...
# 51464       Zimbabwe       ZWE  2016                               14030000.0
# 51465       Zimbabwe       ZWE  2017                               14237000.0
# 51466       Zimbabwe       ZWE  2018                               14439000.0
# 51467       Zimbabwe       ZWE  2019                               14645000.0
# 51468  Åland Islands       ALA  2015                                      NaN
#
#       Continent  \
# ...

# %%
df_2016 = df[df['Year']==2016]
humanize.intword(df['Total population (Gapminder, HYDE & UN)'])
#df_2016 = humanize.intword(df['Total population (Gapminder, HYDE & UN)'])
df_2016
# Out:
#                Entity      Code  Year  \
# 217       Afghanistan       AFG  2016
# 399            Africa       NaN  2016
# 620           Albania       ALB  2016
# 840           Algeria       DZA  2016
# 910    American Samoa       ASM  2016
# ...               ...       ...   ...
# 50648  Western Sahara       ESH  2016
# 50799           World  OWID_WRL  2016
# 51020           Yemen       YEM  2016
# 51243          Zambia       ZMB  2016
# 51464        Zimbabwe       ZWE  2016
#
#        Total population (Gapminder, HYDE & UN) Continent  \
# 217                               3.538300e+07       NaN
# 399                               1.213041e+09       NaN
# 620                               2.886000e+06       NaN
# 840                               4.055100e+07       NaN
# 910                               5.600000e+04       NaN
# ...                                        ...       ...
# 50648                             5.390000e+05       NaN
# ...

# %%
total_ppopulation = []
for value in df_2016['Total population (Gapminder, HYDE & UN)'].iteritems():
    total_ppopulation.append(humanize.intword(value))

total_ppopulation
# Out:
# [(217, 35383000.0),
#  (399, 1213041024.0),
#  (620, 2886000.0),
#  (840, 40551000.0),
#  (910, 56000.0),
#  (1130, 77000.0),
#  (1350, 28842000.0),
#  (1420, 14000.0),
#  (1641, 95000.0),
#  (1861, 43508000.0),
#  (2081, 2936000.0),
#  (2151, 105000.0),
#  (2356, 4476608000.0),
#  (2511, nan),
#  (2730, 24263000.0),
#  (2950, 8747000.0),
#  (3171, 9736000.0),
#  (3392, 378000.0),
#  (3612, 1426000.0),
#  (3832, 157976992.0),
#  (4052, 286000.0),
#  (4273, 9446000.0),
#  (4500, 11354000.0),
#  (4720, 368000.0),
#  (4940, 10872000.0),
#  (5010, 63000.0),
#  (5230, 737000.0),
#  (5450, 11032000.0),
#  (5520, 25000.0),
#  (5740, 3386000.0),
#  (5960, 2160000.0),
#  (6181, 206163008.0),
#  (6252, 29000.0),
#  (6472, 420000.0),
#  (6692, 7152000.0),
#  (6912, 18646000.0),
#  (7132, 10488000.0),
#  (7352, 15766000.0),
#  (7572, 23927000.0),
#  (7792, 36383000.0),
#  (8012, 531000.0),
#  (8082, 63000.0),
#  (8302, 4538000.0),
#  (8522, 14562000.0),
#  (8592, 167000.0),
# ...

# %%
df1 = pd.DataFrame(df_2016['Entity'])
df1['Total Population'] = pd.DataFrame(df['Total population (Gapminder, HYDE & UN)'])
df1['GDP Per Capita'] = pd.DataFrame(df['Real GDP per capita in 2011US$, 2011 benchmark (Maddison Project Database (2018))'])
df1['CO2 emissions Per capita '] = pd.DataFrame(df['Per capita CO2 emissions'])

# %%
df1 = df1.rename(columns={'Total Population':'Total_Population',
                         'GDP Per Capita':'GDP_Per_Capita',
                         'CO2 emissions Per capita':'CO2'})

# %%
df1 = df1.dropna(how='any')
df1
# Out:
#             Entity  Total_Population  GDP_Per_Capita  \
# 217    Afghanistan        35383000.0          1929.0
# 620        Albania         2886000.0         10342.0
# 840        Algeria        40551000.0         14331.0
# 1350        Angola        28842000.0          8453.0
# 1861     Argentina        43508000.0         18875.0
# ...            ...               ...             ...
# 50287    Venezuela        29851000.0         15219.0
# 50507      Vietnam        93640000.0          6062.0
# 51020        Yemen        27168000.0          2506.0
# 51243       Zambia        16363000.0          3479.0
# 51464     Zimbabwe        14030000.0          1534.0
#
#        CO2 emissions Per capita
# 217                     0.244562
# 620                     1.570467
# 840                     3.639334
# 1350                    1.182683
# 1861                    4.597748
# ...                          ...
# 50287                   5.467452
# 50507                   1.959536
# ...

# %%
from bokeh.sampledata.autompg import autompg
from bokeh.models import LinearColorMapper, ColorBar,ColumnDataSource
from bokeh.transform import transform
from bokeh.plotting import figure,show,output_notebook
from bokeh.models import LinearAxis, Range1d

output_notebook()

source = ColumnDataSource(df1)
color_mapper = LinearColorMapper(palette="Viridis256", low=df1['Total_Population'].min(), high=df1['Total_Population'].max())

p = figure(x_axis_label='GDP Per Capita', y_axis_label='CO2 emissions Per capita', tools='', toolbar_location=None)
p.circle(x='GDP_Per_Capita', y='CO2 emissions Per capita ', color=transform('Total_Population', color_mapper), size=20, alpha=0.6, source=df1)

color_bar = ColorBar(color_mapper=color_mapper, label_standoff=12, location=(0,0), title='Total Population')
p.add_layout(color_bar, 'right')

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3331">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="49cd14a4-6963-4289-bc76-907d7691fb41" data-root-id="3334"></div>

# %%
import matplotlib.pyplot as plt
fig,ax = plt.subplots(figsize=(12,8))
plt.scatter(df1['GDP_Per_Capita'],df1['CO2 emissions Per capita '])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-ee5800879942> in <module>
#       2 fig,ax = plt.subplots(figsize=(12,8))
#       3 plt.scatter(df1['GDP_Per_Capita'],df1['CO2 emissions Per capita '])
# ----> 4 plt.xlabel('GDP Per Capita')
#
# TypeError: 'str' object is not callable

# %%
df1['Total_Population'].min()
# Out:
# 71000.0
